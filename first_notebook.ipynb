# %%
print("hello world")
# Out:
# hello world

# %%
bar_labels = ['A','B', 'C', 'D']
bar_heights = [3, 7, 4, 2]

plt.bar(bar_labels, bar_heights)
plt.show()

# %%
# Bar Graph

# %%
#Scatter Graph

# %%
x = ['5', '7', '9', ] # list of numbers
y = ['2', '4','6'] # list of other numbers

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(x,y)
plt.show()
